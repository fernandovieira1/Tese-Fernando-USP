# %%
import pandas as pd

# %%
# Criar um gráfico de barras com dados simulados
df = pd.DataFrame({10, 20, 30, 35}, index=['A', 'B', 'C', 'D'], columns=['X'])

# Gráfico de barras
df.plot(kind='bar')
# Out:
# <Axes: >
